# %%
from dplython import *

# %%
diamonds.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
data1 = diamonds>>select(X.carat,X.cut,X.color,X.clarity,X.depth,X.table,X.price)
plot_data = data1>>group_by(X.cut)>> \
summarize(average_price = X.price.mean())>> \
arrange(-X.average_price)
          
          
plot_data['average_price'] = round(plot_data['average_price'],2)          
plot_data.head()
# Out:
#          cut  average_price
# 3    Premium        4584.26
# 0       Fair        4358.76
# 4  Very Good        3981.76
# 1       Good        3928.86
# 2      Ideal        3457.54

# %%
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5]
plt.bar(plot_data['cut'],plot_data['average_price'],width = .4)
plt.show()

# %%
import pandas as pd
import os
from matplotlib import pyplot as plt
os.chdir("D:/Term-2/Data Visualization/Day-4(18-02-2019)")

# %%
cars =pd.read_excel("Cars.xlsx")

# %%
plt.rcParams['figure.figsize']=[15,5]
plt.boxplot(cars.cty)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x1a908013908>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a90801b358>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1a90801bfd0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1a90801bba8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1a908013a58>,
#   <matplotlib.lines.Line2D at 0x1a908013ef0>]}

# %%
cars.boxplot(column=['cty','hwy'])

# %%
import seaborn as sns
sns.boxplot(data=cars,x='class',y='cty')

# %%
#suv has least mielige
#midsize has an avarage aboe -much more models with varation of city miliage
#two seater has much not variation
#subcomact has more varaition og mielieage
#minivan has negatively skwed

# %%
cars[cars['class']=='midsize'].median()
# Out:
# displ       2.8
# year     2008.0
# cyl         6.0
# cty        18.0
# hwy        27.0
# dtype: float64

# %%
cars[cars['class']=='midsize'].max()
# Out:
# manufacturer    volkswagen
# model               sonata
# displ                  5.3
# year                  2008
# cyl                      8
# trans           manual(m6)
# cty                     23
# hwy                     32
# fl                       r
# class              midsize
# dtype: object

# %%
cars[cars['class']=='compact']
# Out:
#     manufacturer         model  displ  year  cyl       trans  cty  hwy fl  \
# 0           audi            a4    1.8  1999    4    auto(l5)   18   29  p
# 1           audi            a4    1.8  1999    4  manual(m5)   21   29  p
# 2           audi            a4    2.0  2008    4  manual(m6)   20   31  p
# 3           audi            a4    2.0  2008    4    auto(av)   21   30  p
# 4           audi            a4    2.8  1999    6    auto(l5)   16   26  p
# 5           audi            a4    2.8  1999    6  manual(m5)   18   26  p
# 6           audi            a4    3.1  2008    6    auto(av)   18   27  p
# 7           audi    a4 quattro    1.8  1999    4  manual(m5)   18   26  p
# 8           audi    a4 quattro    1.8  1999    4    auto(l5)   16   25  p
# 9           audi    a4 quattro    2.0  2008    4  manual(m6)   20   28  p
# 10          audi    a4 quattro    2.0  2008    4    auto(s6)   19   27  p
# 11          audi    a4 quattro    2.8  1999    6    auto(l5)   15   25  p
# ...

# %%
#compostion-pie and donout chart
ex=(0.1,0,0,0,0.1)
plt.pie(plot_data['average_price'],labels = plot_data['cut'],autopct='%.1f%%',explode=ex)
    
plt.show()

# %%
#Convert the pie chart to a donut chart
#Creating the circle of radius .6 with white color and center cor-ordinates as 0,0
plt.pie(plot_data['average_price'],labels = plot_data['cut'],autopct='%.1f%%',explode=ex)
centre_circle = plt.Circle((0,0),0.60 ,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.show()

# %%
year=[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]
gdp_india=[45,56,76,88,88,123,23,45,67,78]
gdp_pak=[44,55,77,87,87,177,2377,457,677,778]

# %%
plt.plot(year,gdp_india,'ro--')
plt.plot(year,gdp_pak)
plt.show()

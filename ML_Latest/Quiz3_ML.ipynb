# %%
import pandas as pd
import numpy as np
import os
os.chdir("D:/Term-2/Quiz-3")
#from sklearn.linear_model import
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv("Data.csv")
data.head()
# Out:
#    Age          Workclass  fnlwgt   Education  Education_Num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Martial_Status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital_Gain  Capital_Loss  Hours_per_week         Country  Target
# 0          2174             0              40   United-States   <=50K
# ...

# %%
data.isnull().sum()
# Out:
# Age                  0
# Workclass         2214
# fnlwgt               0
# Education            0
# Education_Num        0
# Martial_Status       0
# Occupation        2221
# Relationship         0
# Race                 0
# Sex                  0
# Capital_Gain         0
# Capital_Loss         0
# Hours_per_week       0
# Country            676
# Target               0
# dtype: int64

# %%
data.Workclass.value_counts(),data.Occupation.value_counts()
# Out:
# ( Private             26768
#   Self-emp-not-inc     3006
#   Local-gov            2460
#   State-gov            1581
#   Self-emp-inc         1338
#   Federal-gov          1131
#   Without-pay            16
#   Never-worked            7
#  Name: Workclass, dtype: int64,  Prof-specialty       4906
#   Craft-repair         4830
#   Exec-managerial      4816
#   Adm-clerical         4437
#   Sales                4326
#   Other-service        3884
#   Machine-op-inspct    2392
#   Transport-moving     1848
#   Handlers-cleaners    1614
#   Farming-fishing      1175
#   Tech-support         1095
#   Protective-serv       773
#   Priv-house-serv       193
#   Armed-Forces           11
#  Name: Occupation, dtype: int64)

# %%
data[(data.Workclass.isnull())]
# Out:
#        Age Workclass  fnlwgt      Education  Education_Num  \
# 27      54       NaN  180211   Some-college             10
# 61      32       NaN  293936        7th-8th              4
# 69      25       NaN  200681   Some-college             10
# 77      67       NaN  212759           10th              6
# 106     17       NaN  304873           10th              6
# 128     35       NaN  129305        HS-grad              9
# 149     43       NaN  174662   Some-college             10
# 154     52       NaN  252903        HS-grad              9
# 160     68       NaN   38317        1st-4th              2
# 187     53       NaN  135105      Bachelors             13
# 201     19       NaN  170653        HS-grad              9
# 221     64       NaN  187656        1st-4th              2
# 226     60       NaN   24215           10th              6
# 243     20       NaN  119156   Some-college             10
# 266     19       NaN  218956   Some-college             10
# ...

# %%
data['Workclass'] =np.where(data.Workclass.isnull(),data.Workclass.mode(),data.Workclass)
data['Occupation']=np.where(data.Occupation.isnull(),data.Occupation.mode(),data.Occupation)
data['Country']=np.where(data.Country.isnull(),data.Country.mode(),data.Country)

# %%
data.isnull().sum()
# Out:
# Age               0
# Workclass         0
# fnlwgt            0
# Education         0
# Education_Num     0
# Martial_Status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_Gain      0
# Capital_Loss      0
# Hours_per_week    0
# Country           0
# Target            0
# dtype: int64

# %%
data.head()
# Out:
#    Age          Workclass  fnlwgt   Education  Education_Num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Martial_Status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital_Gain  Capital_Loss  Hours_per_week         Country  Target
# 0          2174             0              40   United-States   <=50K
# ...

# %%
data.Target.value_counts()

data['Target']=np.where((data.Target ==' <=50K'),' <=50K.',data.Target)
data['Target']=np.where((data.Target == ' >50K'),' >50K.',data.Target)
data_index=data[data.Country==' Holand-Netherlands'].index
data=data.drop(data_index,axis=0)
print(data_index)

data.Target.value_counts()
data.shape
# Out:
# Int64Index([19609], dtype='int64')
# (38520, 15)

# %%
test = pd.read_csv("TEST.csv")
test.Target.value_counts()
test.head()
# Out:
#    Age     Workclass  fnlwgt      Education  Education_Num  \
# 0   54       Private  133403            9th              5
# 1   33       Private  150154      Bachelors             13
# 2   22       Private  203076           10th              6
# 3   39       Private  158592   Some-college             10
# 4   23   Federal-gov  215115   Some-college             10
#
#         Martial_Status          Occupation Relationship    Race      Sex  \
# 0   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 1   Married-civ-spouse               Sales      Husband   White     Male
# 2   Married-civ-spouse   Handlers-cleaners      Husband   White     Male
# 3        Never-married               Sales    Own-child   White     Male
# 4        Never-married        Adm-clerical    Own-child   White   Female
#
#    Capital_Gain  Capital_Loss  Hours_per_week         Country   Target
# 0             0          1902              35   United-States   <=50K.
# ...

# %%
test['Workclass'] =np.where(test.Workclass.isnull(),test.Workclass.mode(),test.Workclass)
test['Occupation']=np.where(test.Occupation.isnull(),test.Occupation.mode(),test.Occupation)
test['Country']=np.where(test.Country.isnull(),test.Country.mode(),test.Country)

# %%
test_y=test['Target']
test_x=test.drop('Target',axis=1)
test_x_dum=pd.get_dummies(test_x)
test_x_dum.columns
# Out:
# Index(['Age', 'fnlwgt', 'Education_Num', 'Capital_Gain', 'Capital_Loss',
#        'Hours_per_week', 'Workclass_ Federal-gov', 'Workclass_ Local-gov',
#        'Workclass_ Never-worked', 'Workclass_ Private',
#        ...
#        'Country_ Portugal', 'Country_ Puerto-Rico', 'Country_ Scotland',
#        'Country_ South', 'Country_ Taiwan', 'Country_ Thailand',
#        'Country_ Trinadad&Tobago', 'Country_ United-States',
#        'Country_ Vietnam', 'Country_ Yugoslavia'],
#       dtype='object', length=104)

# %%
x=data.drop('Target',axis=1)
y=data['Target']
x_dummies=pd.get_dummies(x)
x_dummies.columns
# Out:
# Index(['Age', 'fnlwgt', 'Education_Num', 'Capital_Gain', 'Capital_Loss',
#        'Hours_per_week', 'Workclass_ Federal-gov', 'Workclass_ Local-gov',
#        'Workclass_ Never-worked', 'Workclass_ Private',
#        ...
#        'Country_ Portugal', 'Country_ Puerto-Rico', 'Country_ Scotland',
#        'Country_ South', 'Country_ Taiwan', 'Country_ Thailand',
#        'Country_ Trinadad&Tobago', 'Country_ United-States',
#        'Country_ Vietnam', 'Country_ Yugoslavia'],
#       dtype='object', length=104)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x_dummies,y,test_size=0.2)

# %%
mod =AdaBoostClassifier(n_estimators=151)
mod.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=151, random_state=None)

# %%
#accuarcy of traing train data
y_pred = mod.predict(x_train)
accuracy_score(y_pred,y_train)
# Out:
# 0.8676985981308412

# %%
#accuarcy of training test data
y_pred = mod.predict(x_test)
accuracy_score(y_pred,y_test)
# Out:
# 0.8707165109034268

# %%
#accuarcy of actual test data
y_pred = mod.predict(test_x_dum)
accuracy_score(y_pred,test_y)
# Out:
# 0.8663889158027323

# %% [markdown]
# # K-means Clustering

# %%
from sklearn.cluster import KMeans

# %%
kn=KMeans(n_clusters=2)

# %%
data2=data.drop('Target',axis=1)

# %%
data2.head()
# Out:
#    Age          Workclass  fnlwgt   Education  Education_Num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Martial_Status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital_Gain  Capital_Loss  Hours_per_week         Country
# 0          2174             0              40   United-States
# ...

# %%
data2.isnull().sum()
data1=pd.get_dummies(data2)

# %%
kn.fit(data1)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
pd.DataFrame(kn.cluster_centers_,columns=data1.columns)
# Out:
#          Age         fnlwgt  Education_Num  Capital_Gain  Capital_Loss  \
# 0  36.920381  325634.106460       9.897947   1036.150926     82.582574
# 1  39.161696  141699.054354      10.139443   1103.063571     89.304013
#
#    Hours_per_week  Workclass_ Federal-gov  Workclass_ Local-gov  \
# 0       40.325889                0.030145              0.064296
# 1       40.456492                0.029087              0.063711
#
#    Workclass_ Never-worked  Workclass_ Private         ...           \
# 0                 0.000200            0.765849         ...
# 1                 0.000175            0.747643         ...
#
#    Country_ Portugal  Country_ Puerto-Rico  Country_ Scotland  Country_ South  \
# 0           0.000801              0.003605           0.000100        0.002103
# 1           0.001332              0.003680           0.000561        0.002593
#
#    Country_ Taiwan  Country_ Thailand  Country_ Trinadad&Tobago  \
# ...

# %%
d=pd.DataFrame(kn.predict(data1),columns=['x'])
d.x.value_counts()
# Out:
# 1    28535
# 0     9985
# Name: x, dtype: int64

# %% [markdown]
# # Recommedation System

# %%
data.head()
# Out:
#    Age          Workclass  fnlwgt   Education  Education_Num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Martial_Status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital_Gain  Capital_Loss  Hours_per_week         Country   Target
# ...

# %%
data3=pd.get_dummies(data)

# %%
from sklearn.neighbors import NearestNeighbors

# %%
model_kn = NearestNeighbors(metric='cosine',algorithm='brute')
model_kn.fit(data3)
# Out:
# NearestNeighbors(algorithm='brute', leaf_size=30, metric='cosine',
#          metric_params=None, n_jobs=1, n_neighbors=5, p=2, radius=1.0)

# %%
test = data3.iloc[0,:].reshape(1,-1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """Entry point for launching an IPython kernel.

# %%
distances,indices = model_kn.kneighbors(test,n_neighbors=6)
#ind = indicies[0]
recom = [indices[0]]
recom
# Out:
# [array([    0,  3572,  4616,  8826, 29656, 38073], dtype=int64)]

# %%
data.iloc[[0,3572,4616,8826,29656,38073],:]
# Out:
#        Age   Workclass  fnlwgt   Education  Education_Num  \
# 0       39   State-gov   77516   Bachelors             13
# 3572    19     Private   37332     HS-grad              9
# 4616    36     Private  130926   Bachelors             13
# 8826    41     Private  156566   Bachelors             13
# 29657   55     Private  184882   Assoc-voc             11
# 38074   40     Private  145166     HS-grad              9
#
#             Martial_Status         Occupation    Relationship    Race  \
# 0            Never-married       Adm-clerical   Not-in-family   White
# 3572         Never-married     Prof-specialty       Own-child   White
# 4616              Divorced       Adm-clerical   Not-in-family   White
# 8826    Married-civ-spouse    Exec-managerial         Husband   White
# 29657   Married-civ-spouse   Transport-moving         Husband   White
# 38074   Married-civ-spouse       Craft-repair         Husband   White
#
# ...
